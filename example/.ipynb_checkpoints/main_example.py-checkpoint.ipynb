# %%
import sys

sys.path.append('../')

from pyspark.sql import SparkSession
from pyspark.sql import functions as F

from probabilistic_covshift.constants.automl_constants import AutoMLConfig as AutoMLConfig
from probabilistic_covshift.constants.automl_constants import H2OServerInfo as H2OServerInfo
from probabilistic_covshift.constants.main_constants import OriginFeatures as OriginFeatures
from probabilistic_covshift.constants.main_constants import WeightFeatures as WeightFeatures
from probabilistic_covshift.probabilistic_classification_covshift import ProbabilisticClassification

# %%
spark = SparkSession.builder.appName('main').master('local[4]').getOrCreate()

# %%
source_df = spark.createDataFrame([
    ('A', 38.9, 40.0, 55, 'E', 10.0), ('A', 88.9, 50.0, 15, 'E', 20.0), ('B', 18.9, 40.0, 55, 'P', 30.0),
    ('A', 38.9, 50.0, 15, 'E', 10.0), ('B', 48.9, 40.0, 55, 'P', 20.0), ('B', 58.9, 50.0, 15, 'E', 30.0), 
    ('A', 38.9, 40.0, 55, 'P', 10.0), ('B', 98.9, 50.0, 15, 'E', 20.0), ('A', 38.9, 40.0, 55, 'E', 10.0),
    ('A', 88.9, 50.0, 15, 'E', 20.0), ('B', 18.9, 40.0, 55, 'P', 30.0), ('A', 38.9, 50.0, 15, 'E', 10.0),
    ('B', 48.9, 40.0, 55, 'P', 20.0), ('B', 58.9, 50.0, 15, 'E', 30.0), ('A', 38.9, 40.0, 55, 'P', 10.0),
    ('B', 98.9, 50.0, 15, 'E', 20.0), ('A', 38.9, 40.0, 55, 'E', 10.0), ('A', 88.9, 50.0, 15, 'E', 20.0),
    ('B', 18.9, 40.0, 55, 'P', 30.0), ('A', 38.9, 50.0, 15, 'E', 10.0), ('B', 48.9, 40.0, 55, 'P', 20.0),
    ('B', 58.9, 50.0, 15, 'E', 30.0), ('A', 38.9, 40.0, 55, 'P', 10.0), ('B', 98.9, 50.0, 15, 'E', 20.0),
    ('A', 38.9, 40.0, 55, 'E', 10.0), ('A', 88.9, 50.0, 15, 'E', 20.0), ('B', 18.9, 40.0, 55, 'P', 30.0),
    ('A', 38.9, 50.0, 15, 'E', 10.0), ('B', 48.9, 40.0, 55, 'P', 20.0), ('B', 58.9, 50.0, 15, 'E', 30.0), 
    ('A', 38.9, 40.0, 55, 'P', 10.0), ('B', 98.9, 50.0, 15, 'E', 20.0), ('A', 38.9, 40.0, 55, 'E', 10.0),
    ('A', 88.9, 50.0, 15, 'E', 20.0), ('B', 18.9, 40.0, 55, 'P', 30.0), ('A', 38.9, 50.0, 15, 'E', 10.0),
    ('B', 48.9, 40.0, 55, 'P', 20.0), ('B', 58.9, 50.0, 15, 'E', 30.0), ('A', 38.9, 40.0, 55, 'P', 10.0),
    ('B', 98.9, 50.0, 15, 'E', 20.0), ('A', 38.9, 40.0, 55, 'E', 10.0), ('A', 88.9, 50.0, 15, 'E', 20.0),
    ('B', 18.9, 40.0, 55, 'P', 30.0), ('A', 38.9, 50.0, 15, 'E', 10.0), ('B', 48.9, 40.0, 55, 'P', 20.0),
    ('B', 58.9, 50.0, 15, 'E', 30.0), ('A', 38.9, 40.0, 55, 'P', 10.0), ('B', 98.9, 50.0, 15, 'E', 20.0)], 
    ['col_a', 'col_b', 'col_c', 'col_d', 'col_e', 'col_f'])

# %%
target_df = spark.createDataFrame([
    ('A', 48.9, 40.0, 55, 'E', 10.0), ('A', 58.9, 50.0, 15, 'E', 10.0), ('B', 38.9, 40.0, 55, 'P', 30.0),
    ('A', 48.9, 50.0, 15, 'E', 10.0), ('B', 58.9, 40.0, 55, 'P', 10.0), ('B', 38.9, 50.0, 15, 'E', 30.0),
    ('A', 48.9, 40.0, 55, 'P', 10.0), ('B', 58.9, 50.0, 15, 'E', 10.0), ('B', 38.9, 50.0, 15, 'E', 20.0),
    ('A', 48.9, 40.0, 55, 'E', 10.0), ('A', 58.9, 50.0, 15, 'E', 10.0), ('B', 38.9, 40.0, 55, 'P', 30.0),
    ('A', 48.9, 50.0, 15, 'E', 10.0), ('B', 38.9, 40.0, 55, 'P', 10.0), ('B', 38.9, 50.0, 15, 'E', 30.0),
    ('A', 48.9, 40.0, 55, 'P', 10.0), ('B', 38.9, 50.0, 15, 'E', 10.0), ('B', 38.9, 50.0, 15, 'E', 20.0),
    ('A', 58.9, 40.0, 55, 'E', 10.0), ('A', 38.9, 50.0, 15, 'E', 10.0), ('B', 38.9, 40.0, 55, 'P', 30.0),
    ('A', 58.9, 50.0, 15, 'E', 10.0), ('B', 148.9, 140.0, 55, 'P', 10.0), ('B', 38.9, 50.0, 15, 'E', 30.0),
    ('A', 58.9, 40.0, 55, 'P', 110.0), ('B', 198.9, 150.0, 15, 'E', 10.0), ('B', 38.9, 50.0, 15, 'E', 20.0),
    ('A', 58.9, 40.0, 55, 'E', 110.0), ('A', 38.9, 50.0, 15, 'E', 10.0), ('B', 38.9, 140.0, 55, 'P', 30.0),
    ('A', 58.9, 50.0, 15, 'E', 110.0), ('B', 38.9, 40.0, 55, 'P', 10.0), ('B', 38.9, 150.0, 15, 'E', 30.0),
    ('A', 58.9, 40.0, 55, 'P', 110.0), ('B', 38.9, 50.0, 15, 'E', 10.0), ('B', 38.9, 150.0, 15, 'E', 20.0)], 
    ['col_a', 'col_b', 'col_c', 'col_d', 'col_e', 'col_f'])

# %%
automl_conf = {
    AutoMLConfig.DATA: {
        AutoMLConfig.LABEL_COL: OriginFeatures.ORIGIN,
        AutoMLConfig.WEIGHT_COL: WeightFeatures.WEIGHT,
        AutoMLConfig.BASE_TABLE_PATH: 'data/base_table.parquet',
        AutoMLConfig.WEIGHT_PATH: 'data/weight.csv'
    },
    AutoMLConfig.SERVER_CONN_INFO: {
        H2OServerInfo.IP: 'localhost',
        H2OServerInfo.PORT: '54321'
    },
    AutoMLConfig.CROSS_VAL: {
        AutoMLConfig.FOLD_COL: "fold",
        AutoMLConfig.NFOLDS: 8,
    },
    AutoMLConfig.MODELING: {
        AutoMLConfig.MAX_RUNTIME_SECS: 3600,
        AutoMLConfig.MAX_MODELS: 10,
        AutoMLConfig.STOPPING_METRIC: 'logloss',
        AutoMLConfig.SORT_METRIC: 'logloss'
    },
    AutoMLConfig.EXCLUDE_ALGOS: [
        "StackedEnsemble",
        "DeepLearning"
    ],
    AutoMLConfig.MODEL: {
        AutoMLConfig.BEST_MODEL_PATH: 'data/model/'
    },
    AutoMLConfig.SEED: 23
}

# %%
pc = ProbabilisticClassification(source_df, target_df, automl_conf)
pc.run()

# %%
import h2o

# %%
col = [0, 0, 1, 1, 2, 3, 0]
fr = h2o.H2OFrame(list(zip(*[col])))
fr.set_names(['rank'])
mapping = h2o.H2OFrame(list(zip(*[[0,1,2,3],[6,7,8,9]])))
mapping.set_names(['rank', 'outcome'])
merged = fr.merge(mapping,
                  all_x=True,
                  all_y=False,
                  by_x=['rank'],
                  by_y=['rank'],
                  method='auto')
# Out:
# ---------------------------------------------------------------------------
# H2OConnectionError                        Traceback (most recent call last)
# <ipython-input-5-a478f9866d7b> in <module>
#       1 col = [0, 0, 1, 1, 2, 3, 0]
# ----> 2 fr = h2o.H2OFrame(list(zip(*[col])))
#       3 fr.set_names(['rank'])
#       4 mapping = h2o.H2OFrame(list(zip(*[[0,1,2,3],[6,7,8,9]])))
#       5 mapping.set_names(['rank', 'outcome'])
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/frame.py in __init__(self, python_obj, destination_frame, header, separator, column_names, column_types, na_strings, skipped_columns)
#     107         if python_obj is not None:
#     108             self._upload_python_object(python_obj, destination_frame, header, separator,
# --> 109                                        column_names, column_types, na_strings, skipped_columns)
#     110
#     111     @staticmethod
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/frame.py in _upload_python_object(self, python_obj, destination_frame, header, separator, column_names, column_types, na_strings, skipped_columns)
#     148             csv_writer.writerows(data_to_write)
#     149         tmp_file.close()  # close the streams
# --> 150         self._upload_parse(tmp_path, destination_frame, 1, separator, column_names, column_types, na_strings, skipped_columns)
#     151         os.remove(tmp_path)  # delete the tmp file
#     152
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/frame.py in _upload_parse(self, path, destination_frame, header, sep, column_names, column_types, na_strings, skipped_columns)
#     433
#     434     def _upload_parse(self, path, destination_frame, header, sep, column_names, column_types, na_strings, skipped_columns=None):
# --> 435         ret = h2o.api("POST /3/PostFile", filename=path)
#     436         rawkey = ret["destination_frame"]
#     437         self._parse(rawkey, destination_frame, header, sep, column_names, column_types, na_strings, skipped_columns)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/h2o.py in api(endpoint, data, json, filename, save_to)
#     120     """
#     121     # type checks are performed in H2OConnection class
# --> 122     _check_connection()
#     123     return h2oconn.request(endpoint, data=data, json=json, filename=filename, save_to=save_to)
#     124
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/h2o.py in _check_connection()
#    2193 def _check_connection():
#    2194     if not h2oconn or not h2oconn.cluster:
# -> 2195         raise H2OConnectionError("Not connected to a cluster. Did you run `h2o.connect()`?")
#    2196
#    2197 def _connect_with_conf(conn_conf):
#
# H2OConnectionError: Not connected to a cluster. Did you run `h2o.connect()`?

# %%
fr

# %%
mapping
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-603b06cfaa85> in <module>
# ----> 1 mapping
#
# NameError: name 'mapping' is not defined

# %%
merged
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  rank</th><th style="text-align: right;">  outcome</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">        6</td></tr>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">        6</td></tr>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">        6</td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">        7</td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">        7</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">        8</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">        9</td></tr>
# </tbody>
# </table>

# %%
merged['new'] = merged['rank'] * merged['outcome'] / 2
merged['rank','outcome']
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-2dbd4a138ca0> in <module>
#       1 merged['new'] = merged['rank'] * merged['outcome'] / 2
# ----> 2 merged['rank','outcome']
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/IPython/core/displayhook.py in __call__(self, result)
#     260             self.start_displayhook()
#     261             self.write_output_prompt()
# --> 262             format_dict, md_dict = self.compute_format_data(result)
#     263             self.update_user_ns(result)
#     264             self.fill_exec_result(result)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/IPython/core/displayhook.py in compute_format_data(self, result)
#     149
#     150         """
# --> 151         return self.shell.display_formatter.format(result)
#     152
#     153     # This can be set to True by the write_output_prompt method in a subclass
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# </Users/albertus.kelvin/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/decorator.py:decorator-gen-10> in __call__(self, obj)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     397                         if cls is not object \
#     398                                 and callable(cls.__dict__.get('__repr__')):
# --> 399                             return _repr_pprint(obj, self, cycle)
#     400
#     401             return _default_pprint(obj, self, cycle)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     687     """A pprint that just redirects to the normal repr function."""
#     688     # Find newlines and replace them with p.break_()
# --> 689     output = repr(obj)
#     690     for idx,output_line in enumerate(output.splitlines()):
#     691         if idx:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/frame.py in __repr__(self)
#     546             stk = traceback.extract_stack()
#     547             if not ("IPython" in stk[-2][0] and "info" == stk[-2][2]):
# --> 548                 self.show()
#     549         return ""
#     550
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/frame.py in show(self, use_pandas, rows, cols)
#     580             print("This H2OFrame is empty.")
#     581             return
# --> 582         if not self._ex._cache.is_valid(): self._frame()._ex._cache.fill()
#     583         if H2ODisplay._in_zep():
#     584             print("%html " + self._ex._cache._tabulate("html", False, rows=rows))
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/frame.py in _frame(self, rows, rows_offset, cols, cols_offset, fill_cache)
#     698
#     699     def _frame(self, rows=10, rows_offset=0, cols=-1, cols_offset=0, fill_cache=False):
# --> 700         self._ex._eager_frame()
#     701         if fill_cache:
#     702             self._ex._cache.fill(rows=rows, rows_offset=rows_offset, cols=cols, cols_offset=cols_offset)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _eager_frame(self)
#      93         if not self._cache.is_empty(): return
#      94         if self._cache._id is not None: return  # Data already computed under ID, but not cached locally
# ---> 95         self._eval_driver(True)
#      96
#      97     def _eager_scalar(self):  # returns a scalar (or a list of scalars)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _eval_driver(self, top)
#     110
#     111     def _eval_driver(self, top):
# --> 112         exec_str = self._get_ast_str(top)
#     113         res = ExprNode.rapids(exec_str)
#     114         if 'scalar' in res:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _get_ast_str(self, top)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in <listcomp>(.0)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _arg_to_expr(arg)
#     161             return "[]"  # empty list
#     162         if isinstance(arg, ExprNode):
# --> 163             return arg._get_ast_str(False)
#     164         if isinstance(arg, ASTId):
#     165             return str(arg)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _get_ast_str(self, top)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in <listcomp>(.0)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _arg_to_expr(arg)
#     161             return "[]"  # empty list
#     162         if isinstance(arg, ExprNode):
# --> 163             return arg._get_ast_str(False)
#     164         if isinstance(arg, ASTId):
#     165             return str(arg)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _get_ast_str(self, top)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in <listcomp>(.0)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _arg_to_expr(arg)
#     161             return "[]"  # empty list
#     162         if isinstance(arg, ExprNode):
# --> 163             return arg._get_ast_str(False)
#     164         if isinstance(arg, ASTId):
#     165             return str(arg)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _get_ast_str(self, top)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in <listcomp>(.0)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _arg_to_expr(arg)
#     161             return "[]"  # empty list
#     162         if isinstance(arg, ExprNode):
# --> 163             return arg._get_ast_str(False)
#     164         if isinstance(arg, ASTId):
#     165             return str(arg)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _get_ast_str(self, top)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in <listcomp>(.0)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _arg_to_expr(arg)
#     161             return "[]"  # empty list
#     162         if isinstance(arg, ExprNode):
# --> 163             return arg._get_ast_str(False)
#     164         if isinstance(arg, ASTId):
#     165             return str(arg)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _get_ast_str(self, top)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in <listcomp>(.0)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _arg_to_expr(arg)
#     161             return "[]"  # empty list
#     162         if isinstance(arg, ExprNode):
# --> 163             return arg._get_ast_str(False)
#     164         if isinstance(arg, ASTId):
#     165             return str(arg)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _get_ast_str(self, top)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in <listcomp>(.0)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _arg_to_expr(arg)
#     161             return "[]"  # empty list
#     162         if isinstance(arg, ExprNode):
# --> 163             return arg._get_ast_str(False)
#     164         if isinstance(arg, ASTId):
#     165             return str(arg)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _get_ast_str(self, top)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in <listcomp>(.0)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _arg_to_expr(arg)
#     161             return "[]"  # empty list
#     162         if isinstance(arg, ExprNode):
# --> 163             return arg._get_ast_str(False)
#     164         if isinstance(arg, ASTId):
#     165             return str(arg)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _get_ast_str(self, top)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in <listcomp>(.0)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _arg_to_expr(arg)
#     161             return "[]"  # empty list
#     162         if isinstance(arg, ExprNode):
# --> 163             return arg._get_ast_str(False)
#     164         if isinstance(arg, ASTId):
#     165             return str(arg)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _get_ast_str(self, top)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in <listcomp>(.0)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _arg_to_expr(arg)
#     161             return "[]"  # empty list
#     162         if isinstance(arg, ExprNode):
# --> 163             return arg._get_ast_str(False)
#     164         if isinstance(arg, ASTId):
#     165             return str(arg)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _get_ast_str(self, top)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in <listcomp>(.0)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _arg_to_expr(arg)
#     161             return "[]"  # empty list
#     162         if isinstance(arg, ExprNode):
# --> 163             return arg._get_ast_str(False)
#     164         if isinstance(arg, ASTId):
#     165             return str(arg)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _get_ast_str(self, top)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in <listcomp>(.0)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _arg_to_expr(arg)
#     161             return "[]"  # empty list
#     162         if isinstance(arg, ExprNode):
# --> 163             return arg._get_ast_str(False)
#     164         if isinstance(arg, ASTId):
#     165             return str(arg)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _get_ast_str(self, top)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in <listcomp>(.0)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _arg_to_expr(arg)
#     161             return "[]"  # empty list
#     162         if isinstance(arg, ExprNode):
# --> 163             return arg._get_ast_str(False)
#     164         if isinstance(arg, ASTId):
#     165             return str(arg)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _get_ast_str(self, top)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in <listcomp>(.0)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _arg_to_expr(arg)
#     161             return "[]"  # empty list
#     162         if isinstance(arg, ExprNode):
# --> 163             return arg._get_ast_str(False)
#     164         if isinstance(arg, ASTId):
#     165             return str(arg)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _get_ast_str(self, top)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in <listcomp>(.0)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _arg_to_expr(arg)
#     161             return "[]"  # empty list
#     162         if isinstance(arg, ExprNode):
# --> 163             return arg._get_ast_str(False)
#     164         if isinstance(arg, ASTId):
#     165             return str(arg)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _get_ast_str(self, top)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in <listcomp>(.0)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _arg_to_expr(arg)
#     161             return "[]"  # empty list
#     162         if isinstance(arg, ExprNode):
# --> 163             return arg._get_ast_str(False)
#     164         if isinstance(arg, ASTId):
#     165             return str(arg)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _get_ast_str(self, top)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in <listcomp>(.0)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _arg_to_expr(arg)
#     161             return "[]"  # empty list
#     162         if isinstance(arg, ExprNode):
# --> 163             return arg._get_ast_str(False)
#     164         if isinstance(arg, ASTId):
#     165             return str(arg)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _get_ast_str(self, top)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in <listcomp>(.0)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _arg_to_expr(arg)
#     161             return "[]"  # empty list
#     162         if isinstance(arg, ExprNode):
# --> 163             return arg._get_ast_str(False)
#     164         if isinstance(arg, ASTId):
#     165             return str(arg)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _get_ast_str(self, top)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in <listcomp>(.0)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _arg_to_expr(arg)
#     161             return "[]"  # empty list
#     162         if isinstance(arg, ExprNode):
# --> 163             return arg._get_ast_str(False)
#     164         if isinstance(arg, ASTId):
#     165             return str(arg)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _get_ast_str(self, top)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in <listcomp>(.0)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _arg_to_expr(arg)
#     161             return "[]"  # empty list
#     162         if isinstance(arg, ExprNode):
# --> 163             return arg._get_ast_str(False)
#     164         if isinstance(arg, ASTId):
#     165             return str(arg)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _get_ast_str(self, top)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in <listcomp>(.0)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _arg_to_expr(arg)
#     161             return "[]"  # empty list
#     162         if isinstance(arg, ExprNode):
# --> 163             return arg._get_ast_str(False)
#     164         if isinstance(arg, ASTId):
#     165             return str(arg)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _get_ast_str(self, top)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in <listcomp>(.0)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _arg_to_expr(arg)
#     161             return "[]"  # empty list
#     162         if isinstance(arg, ExprNode):
# --> 163             return arg._get_ast_str(False)
#     164         if isinstance(arg, ASTId):
#     165             return str(arg)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _get_ast_str(self, top)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in <listcomp>(.0)
#     149             return self._cache._id  # Data already computed under ID, but not cached
#     150         assert isinstance(self._children,tuple)
# --> 151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
#     152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _arg_to_expr(arg)
#     161             return "[]"  # empty list
#     162         if isinstance(arg, ExprNode):
# --> 163             return arg._get_ast_str(False)
#     164         if isinstance(arg, ASTId):
#     165             return str(arg)
#
# ~/Documents/GLAIR_OWN/invstr-credit-scoring/env/lib/python3.7/site-packages/h2o/expr.py in _get_ast_str(self, top)
#     150         assert isinstance(self._children,tuple)
#     151         exec_str = "({} {})".format(self._op, " ".join([ExprNode._arg_to_expr(ast) for ast in self._children]))
# --> 152         gc_ref_cnt = len(gc.get_referrers(self))
#     153         if top or gc_ref_cnt >= ExprNode.MAGIC_REF_COUNT:
#     154             self._cache._id = _py_tmp_key(append=h2o.connection().session_id)
#
# KeyboardInterrupt:

# %%
h2o.remove_all()
